# %% [markdown]
# # Crawling Data

# %% [markdown]
# This file is part of my work on Udacity's Nano Degree Programme.
#
# As capstone project I compare the performance of a machine learning model in predicting matches of the 2020 UEFA European Football Championship with my personal bets in a football guessing game played on the platform www.kicktipp.de

# %% [markdown]
# In this notebook we acquire football statistics of matches played in
# - UEFA Nations League 2018/19
# - UEFA Nations League 2020/21
# - UEFA Euro 2020 qualifying
# and the results of the matches played in the 2020 UEFA European Football Championship.
#
# This is done by crawling wikipedia and the corresponding games on the UEFA page. The parsing of the HTML code is done using BeautifulSoup.

# %%
import numpy as np
import pandas as pd

# %%
import os
import time
import json

# %%
import requests
from urllib.parse import urljoin

# %%
from bs4 import BeautifulSoup

# %%
path_output = '../data/'

# %% [markdown]
# ## Auxiliary Functions

# %%
def request_page_and_generate_soup(url):
    '''
    INPUT:  URL of a web page
    OUTPUT: Soup made by BeautifulSoup that contains the HTML-code of the page
    '''
    
    try:
        # A delay of three seconds such that we do not make too many requests in a short time by mistake
        time.sleep(3)

        content = requests.get(url)
        text    = content.text
        soup    = BeautifulSoup(text)

        return soup
    
    except:
        return None

# %% [markdown]
# ## Function to Extract all URLs of UEFA Games from Wikipedia

# %%
def find_all_match_urls_from_wiki_page(wiki_url):
    '''
    INPUT:       URL of a wikipedia page
    OUTPUT:      URLs of football games on the UEFA web page
        
    DESCRIPTION: We perform a http-request to wikipedia. (A time delay of three seconds is included to avoid making
                 get-requests too often in a second.)
                 The source code of the page is parsed using BeautifulSoup. Then, we extract all URLs to games on the UEFA 
                 web page. They all have te name 'Report'.
    '''
    all_urls_matches = []
    
    try:
        wiki_soup = request_page_and_generate_soup(wiki_url)
        
        # The name of the links of the matches on the UEFA web page is 'Report'
        all_urls_matches = [link['href'] for link in wiki_soup.find_all('a') if link.text == 'Report']
    except:
        pass
    
    return all_urls_matches

# %% [markdown]
# ## Process all UEFA pages

# %%
def get_feature(soup, elem_type, parameter, name):
    '''
    INPUT:  Soup and different HTML-parameters.
    OUTPUT: The feature from the soup specified by the HTML-elements.
    '''
    try:
        return soup.find(elem_type, {parameter : name}).text
    except:
        return np.nan

# %%
def extract_stats_from_stats_page(uefa_stats_page_soup):
    '''
    INPUT:  Soup of the corresponding uefa-page containing the statistics of a football game.
    OUTPUT: Several information from the statistics stored in a dictionary.
    '''
    
    # The features we want to extract from the page and the corresponding HTML-information
    dict_feat = {'goals_home' : ("div", "data-bind", "text: homeGoalsScored"),
                 'goals_away' : ("div", "data-bind", "text: awayGoalsScored"),
                 'attempts_total_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'attempts'}) ? _.find(homeTeam.statistics,{name:'attempts'}).value : 0"),
                 'attempts_total_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'attempts'}) ? _.find(awayTeam.statistics,{name:'attempts'}).value : 0"),
                 'attempts_off_target_home' : ("div", "data-bind", "text: homeAttempsOff"),
                 'attempts_off_target_away' : ("div", "data-bind", "text: awayAttempsOff"),
                 'attempts_on_target_home' : ("div", "data-bind", "text: homeAttempsOn"),
                 'attempts_on_target_away' : ("div", "data-bind", "text: awayAttempsOn"),
                 'attempts_blocked_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'attempts_blocked'}) ? _.find(homeTeam.statistics,{name:'attempts_blocked'}).value : 0"),
                 'attempts_blocked_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'attempts_blocked'}) ? _.find(awayTeam.statistics,{name:'attempts_blocked'}).value : 0"),
                 'corners_home' : ("div", "data-bind", "text: homeCorner"),
                 'corners_away' : ("div", "data-bind", "text: awayCorner"),
                 'offsides_home' : ("div", "data-bind", "text: homeOffside"),
                 'offsides_away' : ("div", "data-bind", "text: awayOffside"),
                 'possession_home' : ("div", "data-bind", "text: homeBallPossession + '%'"),
                 'possession_away' : ("div", "data-bind", "text: awayBallPossession + '%'"),
                 'passes_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'passes_attempted'}) ? _.find(homeTeam.statistics,{name:'passes_attempted'}).value : 0"),
                 'passes_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'passes_attempted'}) ? _.find(awayTeam.statistics,{name:'passes_attempted'}).value : 0"),
                 'passes_completed_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'passes_completed'}) ? _.find(homeTeam.statistics,{name:'passes_completed'}).value : 0"),
                 'passes_completed_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'passes_completed'}) ? _.find(awayTeam.statistics,{name:'passes_completed'}).value : 0"),
                 'balls_recovered_home' : ("div", "data-bind", "text: homeRecoveredBalls"),
                 'balls_recovered_away' : ("div", "data-bind", "text: awayRecoveredBalls"),
                 'tackles_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'tackles'}) ? _.find(homeTeam.statistics,{name:'tackles'}).value : 0"),
                 'tackles_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'tackles'}) ? _.find(awayTeam.statistics,{name:'tackles'}).value : 0"),
                 'blocks_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'blocked'}) ? _.find(homeTeam.statistics,{name:'blocked'}).value : 0"),
                 'blocks_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'blocked'}) ? _.find(awayTeam.statistics,{name:'blocked'}).value : 0"),
                 'clearances_home' : ("div", "data-bind", "text: _.find(homeTeam.statistics,{name:'clearance_completed'}) ? _.find(homeTeam.statistics,{name:'clearance_completed'}).value : 0"),
                 'clearances_away' : ("div", "data-bind", "text: _.find(awayTeam.statistics,{name:'clearance_completed'}) ? _.find(awayTeam.statistics,{name:'clearance_completed'}).value : 0"),
                 'passes_accuracy_home' : ("span", "data-bind", "text: homePassesCompletion"),
                 'passes_accuracy_away' : ("span", "data-bind", "text: awayPassesCompletion")
               }

    # The dictionary that stores the information.
    dict_feat_info = {}

    # Extract the information from the soup
    for feat in dict_feat:
        dict_feat_info[feat] = get_feature(uefa_stats_page_soup, dict_feat[feat][0], dict_feat[feat][1], dict_feat[feat][2])

    return dict_feat_info

# %%
def extract_stats_from_main_page(uefa_main_page_soup):
    '''
    INPUT:  Soup of the UEFA main page in case that there is no specific statistics page.
    OUTPUT: Several information from the statistics stored in a dictionary.
    '''
    
    # The features we want to extract from the page and the corresponding HTML-information
    dict_feat = {'goals_home' : ("div", "class", "goals-scored--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'goals_away' : ("div", "class", "goals-scored--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'attempts_blocked_home' : ("div", "class", "blocked--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'attempts_blocked_away' : ("div", "class", "blocked--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'corners_home' : ("div", "class", "corner--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'corners_away' : ("div", "class", "corner--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'offsides_home' : ("div", "class", "offside--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'offsides_away' : ("div", "class", "offside--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'possession_home' : ("div", "class", "ball-possession-value graph-circle-number-value graph-circle-number-value__home-team"),
                 'possession_away' : ("div", "class", "ball-possession-value graph-circle-number-value graph-circle-number-value__away-team"),
                 'passes_home' : ("div", "class", "passes-value graph-bar--number-value graph-bar--number-value__home-team"),
                 'passes_away' : ("div", "class", "passes-value graph-bar--number-value graph-bar--number-value__away-team"),
                 'passes_completed_home' : ("div", "class", "passes-completed-value graph-bar--number-value graph-bar--number-value__home-team"),
                 'passes_completed_away' : ("div", "class", "passes-completed-value graph-bar--number-value graph-bar--number-value__away-team"),
                 'balls_recovered_home' : ("div", "class", "balls-recovered--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'balls_recovered_away' : ("div", "class", "balls-recovered--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'tackles_home' : ("div", "class", "taclkles--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'tackles_away' : ("div", "class", "taclkles--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'blocks_home' : ("div", "class", "blocks-completed--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'blocks_away' : ("div", "class", "blocks-completed--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'clearances_home' : ("div", "class", "clearances-completed--value graph-bar--number-value graph-bar--number-value__home-team"),
                 'clearances_away' : ("div", "class", "clearances-completed--value graph-bar--number-value graph-bar--number-value__away-team"),
                 'passes_accuracy_home' : ("span", "data-bind", "text: homePassesCompletion"),
                 'passes_accuracy_away' : ("span", "data-bind", "text: awayPassesCompletion")
                }
    
    # The following dictionary stores the information on the processed game.
    dict_feat_info = {}
    
    for feat in dict_feat:
        dict_feat_info[feat] = get_feature(uefa_main_page_soup, dict_feat[feat][0], dict_feat[feat][1], dict_feat[feat][2])
    
    # Due to a different design of the web page, we have to handle the information about the attemps in a different way
    # than in the case that there is a specific containing the statistics.
    
    try:
        attempts_home = [e.text for e in uefa_main_page_soup.find_all('div', {'class' : 'total-attempts--value graph-bar--number-value graph-bar--number-value__home-team'})]
        attempts_away = [e.text for e in uefa_main_page_soup.find_all('div', {'class' : 'total-attempts--value graph-bar--number-value graph-bar--number-value__away-team'})]
        
        dict_feat_info['attempts_total_home'] = attempts_home[0]
        dict_feat_info['attempts_on_target_home'] = attempts_home[1]
        dict_feat_info['attempts_off_target_home'] = attempts_home[2]
        
        dict_feat_info['attempts_total_away'] = attempts_away[0]
        dict_feat_info['attempts_on_target_away'] = attempts_away[1]
        dict_feat_info['attempts_off_target_away'] = attempts_away[2]
        
    except:
        feat_attempts = ['attempts_total_home', 'attempts_on_target_home', 'attempts_off_target_home',
                         'attempts_total_away', 'attempts_on_target_away', 'attempts_off_target_away'
                        ]
        
        for feat in feat_attempts:
            dict_feat_info[feat] = np.nan
            
    return dict_feat_info

# %%
def get_teams_and_date(soup):
    '''
    INPUT: Soup
    OUTPUT: Outputs a dictionary that contains the name of the home team, the away team and the date of the match.
    '''
    dic_teams_and_date = {}
    
    try:
        scripts = soup.find_all('script', {'type' : 'application/ld+json'})
        information = [json.loads(script.text) for script in scripts]
        
        dic_teams_and_date['team_home'] = information[1]['homeTeam']['name']
        dic_teams_and_date['team_away'] = information[1]['awayTeam']['name']
        dic_teams_and_date['date'] = information[1]['startDate']
        
    except:
        dic_teams_and_date['team_home'] = np.nan
        dic_teams_and_date['team_away'] = np.nan
        dic_teams_and_date['date'] = np.nan
        
    return dic_teams_and_date

# %%
def get_url_of_stats_page(uefa_main_page_url, uefa_main_page_soup):
    '''
    INPUT:  URL of the main page of a game played.
    OUPTUT: URL of the corresponding statistics page in case it exists.
    '''
    try:
        url_of_stats_rel = [link['href'] for link in uefa_main_page_soup.find_all('a') if link.text.strip() == 'Stats'][0]
        url_of_stats_abs = urljoin(uefa_main_page_url, url_of_stats_rel)

        return url_of_stats_abs
    except:
        return None

# %%
def extract_information_from_uefa(uefa_main_page_url):
    '''
    INPUT:  URL of the main page of a played game.
    OUTPUT: Outputs a dictionary that stores features for this game (home team, away team, date, several game statistics...)
    
    DESCRIPTION: At first we request the main page and extract the date and the teams. Unfortunately, the UEFA changed their
                 page design over time. Therefore, we investigate if there is a link to another page containing the statistics.
                 If that is true, then we have to make another request and process this statistics page afterwards. Otherwise,
                 we can parse the information from the main page.
    '''
    
    print('Process the following url: ', uefa_main_page_url)
    
    # The following dictionary will contain all information on the game and will be returned by the function in the end.
    dict_result = {}
    dict_result['url'] = uefa_main_page_url
    
    # Get Main Page Soup
    print('Request main page...')
    uefa_main_page_soup = request_page_and_generate_soup(uefa_main_page_url)
    
    # Parse Date, Home Team and Away Team
    dict_teams_and_date = get_teams_and_date(uefa_main_page_soup)
        
    # Try to find a link to a statistics page
    url_of_stats_page = get_url_of_stats_page(uefa_main_page_url, uefa_main_page_soup)
    
    # Extract features
    if url_of_stats_page == None:
        print('Extract features from main page...')
        dict_info = extract_stats_from_main_page(uefa_main_page_soup)
    else:
        print('Request stats page...')
        uefa_stats_page_soup = request_page_and_generate_soup(url_of_stats_page)
        dict_info = extract_stats_from_stats_page(uefa_stats_page_soup)
    
    # Update 
    dict_result.update(dict_teams_and_date)
    dict_result.update(dict_info)
    
    print()
        
    return dict_result

# %%
def get_teams_and_result(soup):
    '''
    INPUT: Soup
    OUTPUT: Outputs a dictionary that contains the name of home team, the away team and the date of the match.
    
    DESCRIPTION: This function is used for grabbing the the relevant information from the games played in UEFA Euro 2020.
                 Here, we are only interested in the teams and the result. When extracting the result, we have to take into
                 account that we are interested in the result after a possible penalty shootout.
    '''
    dic_teams_and_result = {}
    
    try:
        scripts = soup.find_all('script', {'type' : 'application/ld+json'})
        information = [json.loads(script.text) for script in scripts]
        
        dic_teams_and_result['team_home'] = information[1]['homeTeam']['name']
        dic_teams_and_result['team_away'] = information[1]['awayTeam']['name']
        dic_teams_and_result['goals_home'] = int(information[1]['name'].split()[1].split('-')[0])
        dic_teams_and_result['goals_away'] = int(information[1]['name'].split()[1].split('-')[1])
        
    except:
        dic_teams_and_result['team_home'] = np.nan
        dic_teams_and_result['team_away'] = np.nan
        dic_teams_and_result['goals_home'] = np.nan
        dic_teams_and_result['goals_away'] = np.nan
        
    try:
        result_penalties = soup.find('div', {'class' : 'js-post-match-penalties-score post-match-penalties-score'}).text
        goals_home_after_p = result_penalties.strip()[1:].split()[0].split('-')[0]
        goals_away_after_p = result_penalties.strip()[1:].split()[0].split('-')[1]
        
        dic_teams_and_result['goals_home'] += int(goals_home_after_p)
        dic_teams_and_result['goals_away'] += int(goals_away_after_p)
        
    except:
        pass
        
    return dic_teams_and_result

# %%
def extract_teams_and_result_from_uefa(uefa_main_page_url):
    '''
    INPUT:  URL of a game played in UEFA Euro 2020.
    OUTPUT: Dictionary containing the teams, which played the game and the result.
    '''
    
    print('Process the following url: ', uefa_main_page_url)
    
    dict_result = {}
    dict_result['url'] = uefa_main_page_url
    
    # Get Main Page Soup
    print('Request main page...')
    uefa_main_page_soup = request_page_and_generate_soup(uefa_main_page_url)
    
    
    # Parse Date, Home Team and Away Team
    dict_teams_and_result = get_teams_and_result(uefa_main_page_soup)
    
    dict_result.update(dict_teams_and_result)
    
    return dict_result

# %% [markdown]
# ### Function to Aggregate Information

# %%
def generate_df_from_information(list_of_dicts):
    '''
    INPUT:  List of dictionaries, which contain the information and statistics of matches
    OUTPUT: All information aggregated in a single dataframe and a list of urls, where the crawling failed.
    '''
    
    df = pd.DataFrame(list_of_dicts)
    
    # All URLs where the crawling failed
    urls_failure = df[df['goals_home'].isnull()]['url']
    
    df = df[df['goals_home'].notnull()]
    
    return df, urls_failure

# %% [markdown]
# ## Crawl Data

# %% [markdown]
# ### Crawl Matches Played before UEFA Euro 2020
#
# In this part we crawl all the data of the games played before the UEFA Euro 2020. The statistics of these games serve as basis for the training of a ML model.

# %% [markdown]
# #### Crawl data from wikipedia

# %%
# The URLs of the wikipedia pages that contain the links to the pages of the UEFA containing the match information
wiki_urls = ['https://en.wikipedia.org/wiki/2020%E2%80%9321_UEFA_Nations_League_A', 
             'https://en.wikipedia.org/wiki/2020%E2%80%9321_UEFA_Nations_League_B',
             'https://en.wikipedia.org/wiki/2020%E2%80%9321_UEFA_Nations_League_C',
             'https://en.wikipedia.org/wiki/2020%E2%80%9321_UEFA_Nations_League_D',
             'https://en.wikipedia.org/wiki/2018%E2%80%9319_UEFA_Nations_League_A',
             'https://en.wikipedia.org/wiki/2018%E2%80%9319_UEFA_Nations_League_B',
             'https://en.wikipedia.org/wiki/2018%E2%80%9319_UEFA_Nations_League_C',
             'https://en.wikipedia.org/wiki/2018%E2%80%9319_UEFA_Nations_League_D',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_A',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_B',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_C',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_D',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_E',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_F',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_G',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_H',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_I',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_Group_J',
             'https://en.wikipedia.org/wiki/UEFA_Euro_2020_qualifying_play-offs'
             ]

# %%
uefa_all_match_urls = [find_all_match_urls_from_wiki_page(wiki_url) for wiki_url in wiki_urls]
uefa_all_match_urls_flattened = [url for urls_competition in uefa_all_match_urls for url in urls_competition]

# %% [markdown]
# #### Crawl data from UEFA: First attempt

# %%
game_information = [extract_information_from_uefa(url) for url in uefa_all_match_urls_flattened]
# Out:
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029980/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029979/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030010/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030007/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030025/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030024/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030054/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030055/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030098/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030099/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030124/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030121/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029987/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029993/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030017/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030019/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030034/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030033/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030062/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030060/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030079/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030082/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030104/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030105/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029991/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029992/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030016/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030018/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030035/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030032/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030063/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030061/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030080/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030081/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030109/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030108/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029969/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029970/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030001/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030000/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030046/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030047/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030069/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030070/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030086/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030087/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030115/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030114/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030758/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030759/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030760/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030761/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029983/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029984/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030009/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030011/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030030/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030026/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030058/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030051/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030095/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030096/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030123/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030125/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029982/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029981/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030008/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030013/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030028/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030027/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030057/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030056/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030100/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030101/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030122/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030126/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029971/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029972/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029996/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029998/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030036/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030037/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030064/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030065/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030094/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030102/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030127/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030128/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029975/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029973/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030002/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030003/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030048/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030043/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030072/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030073/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030090/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030088/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030117/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030116/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029990/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029989/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030020/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030021/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030040/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030038/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030059/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030066/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030078/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030084/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030111/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030110/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029994/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029988/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030015/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030014/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030023/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030029/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030050/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030052/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030093/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030085/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030113/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030112/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029977/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029974/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029997/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029999/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030042/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030049/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030071/
# Request main page...
# Request stats page...
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030076/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030091/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030089/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030118/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030119/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029985/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029986/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030006/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030012/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030045/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030044/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030074/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030075/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030083/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030077/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030106/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030107/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029976/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029978/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030004/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030005/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030041/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030039/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030067/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030068/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030103/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030097/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030129/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030130/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2029995/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030022/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030031/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030053/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030092/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030120/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024025/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024026/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024027/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024028/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024029/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024030/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024031/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024032/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024033/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024034/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024035/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024036/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024019/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024020/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024021/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024023/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024024/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024022/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024042/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024040/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024041/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024038/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024039/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024037/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000956/match=2024419/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000956/match=2024420/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000957/match=2024421/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000958/match=2024422/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024053/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024054/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024052/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024049/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024050/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024051/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024081/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024079/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024080/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024082/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024083/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024084/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024089/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024090/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024088/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024085/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024086/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024087/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024116/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024117/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024115/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024120/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024118/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024119/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024043/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024044/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024045/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024047/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024048/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024046/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024095/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024098/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024093/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024094/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024101/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024102/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024092/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024099/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024100/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024091/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024097/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024096/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024151/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024150/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024153/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024146/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024155/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024148/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024145/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024154/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024156/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024147/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024149/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024152/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024140/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024139/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024143/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024136/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024134/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024141/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024135/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024144/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024133/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024142/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024138/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024137/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024055/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024056/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024057/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024058/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024059/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024060/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024061/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024062/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024063/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024064/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024065/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024066/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024068/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024067/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024069/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024070/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024071/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024072/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024073/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024074/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024075/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024076/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024077/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024078/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024104/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024103/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024105/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024106/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024108/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024107/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024110/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024109/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024112/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024111/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024113/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024114/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024121/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024122/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024123/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024124/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024126/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024125/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024127/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024128/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024130/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024129/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024132/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/season=2019/matches/round=2000959/match=2024131/index.html
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026026/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026027/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026052/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026053/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026067/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026068/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026141/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026142/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026176/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026178/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026209/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026210/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026226/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026227/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026125/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026126/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026092/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026093/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025995/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025996/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026028/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026029/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026054/
# ...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026150/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026151/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026152/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026172/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026185/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026187/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026203/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026204/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026205/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026221/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026222/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026223/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026123/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026124/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026137/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026108/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026114/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026115/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026012/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026013/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026014/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026030/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026031/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026032/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026051/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026056/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026057/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026074/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026081/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026087/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026158/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026159/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026160/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026181/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026184/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026186/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026213/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026214/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026215/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026230/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026231/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026232/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026129/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026130/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026131/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026091/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026096/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026097/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025997/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025998/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025999/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026016/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026025/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026024/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026042/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026045/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026050/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026083/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026088/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026089/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026153/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026161/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026162/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026188/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026189/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026190/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026206/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026207/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026208/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026216/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026224/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026225/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026116/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026119/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026120/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026106/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026109/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026110/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026015/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025992/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2025991/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026038/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026039/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026040/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026058/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026064/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026065/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026084/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026085/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026090/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026163/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026164/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026165/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026166/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026173/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026174/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026195/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026197/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026198/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026236/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026239/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026240/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026138/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026139/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026140/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026098/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026099/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026105/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026005/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026006/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2026007/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028564/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028565/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028572/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028566/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028567/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028573/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028568/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028569/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028574/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028570/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028571/
# Request main page...
# Extract features from main page...
#
# Process the following url:  https://www.uefa.com/uefaeuro/match/2028575/
# Request main page...
# Extract features from main page...

# %%
df_1, urls_failures_1 = generate_df_from_information(game_information)

# %%
urls_failures_1
# Out:
# 47    https://www.uefa.com/uefanationsleague/match/2...
# 48    https://www.uefa.com/uefanationsleague/match/2...
# 49    https://www.uefa.com/uefanationsleague/match/2...
# 50    https://www.uefa.com/uefanationsleague/match/2...
# 51    https://www.uefa.com/uefanationsleague/match/2...
# 61    https://www.uefa.com/uefanationsleague/match/2...
# Name: url, dtype: object

# %% [markdown]
# #### Crawl data from UEFA: Second attempt

# %%
# Usually, we fail on crawling a couple of matches.
# Therefore, we make a second attempt on pages where we failed.

# %%
game_information_2 = [extract_information_from_uefa(url) for url in urls_failures_1]
# Out:
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030114/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030758/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030759/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030760/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030761/
# Request main page...
# Request stats page...
#
# Process the following url:  https://www.uefa.com/uefanationsleague/match/2030096/
# Request main page...
# Request stats page...

# %%
df_2, urls_failures_2 = generate_df_from_information(game_information_2)

# %%
urls_failures_2
# Out:
# 0    https://www.uefa.com/uefanationsleague/match/2...
# 1    https://www.uefa.com/uefanationsleague/match/2...
# 2    https://www.uefa.com/uefanationsleague/match/2...
# 3    https://www.uefa.com/uefanationsleague/match/2...
# 4    https://www.uefa.com/uefanationsleague/match/2...
# 5    https://www.uefa.com/uefanationsleague/match/2...
# Name: url, dtype: object

# %% [markdown]
# #### Merge Data From Both Attempts and Export

# %%
# Aggregate the information gained in both attempts in a single dataframe
df_information = pd.concat([df_1, df_2]).reset_index(drop = True)

# %%
# Export the data into the folder data.
file_name_matches_training = 'matches_training_ml.xlsx'

df_information.to_excel(os.path.join(path_output, file_name_matches_training), index = False, encoding = 'iso-8859-1')

# %% [markdown]
# ### Crawl Results UEFA Euro 2021
#
# Here, we crawl the information of the games played at UEFA Euro 2020. For these matches we are only interested in the teams taking part and the results of the matches. These games will form the validation set in the end.

# %%
em_matches_urls = find_all_match_urls_from_wiki_page('https://en.wikipedia.org/wiki/UEFA_Euro_2020')

# %%
# Crawl information from matches of UEFA Euro 2020
matches_information_em = [extract_teams_and_result_from_uefa(url) for url in em_matches_urls]
# Out:
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024447/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024448/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024457/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024458/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024467/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024468/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024449/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024450/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024460/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024459/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024469/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024470/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024442/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024441/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024444/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024443/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024445/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024446/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024451/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024452/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024462/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024461/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024472/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024471/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024454/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024453/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024464/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024463/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024473/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024474/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024455/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024456/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024465/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024466/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024476/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024475/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024478/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024477/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024480/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024479/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024482/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024481/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024484/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024483/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024485/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024486/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024488/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024487/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024489/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024490/
# Request main page...
# Process the following url:  https://www.uefa.com/uefaeuro-2020/match/2024491/
# Request main page...

# %%
df_matches_em_crawling = pd.DataFrame(data = matches_information_em)

# %%
# In some cases the crawling failed
df_matches_em_crawling[df_matches_em_crawling['team_home'].isnull()]
# Out:
#                                                   url team_home team_away  \
# 16  https://www.uefa.com/uefaeuro-2020/match/2024445/       NaN       NaN
# 23  https://www.uefa.com/uefaeuro-2020/match/2024471/       NaN       NaN
# 46  https://www.uefa.com/uefaeuro-2020/match/2024488/       NaN       NaN
#
#     goals_home  goals_away
# 16         NaN         NaN
# 23         NaN         NaN
# 46         NaN         NaN

# %%
# The information of the missing games is added by hand
data_missing_matches = [{'url' : 'https://www.uefa.com/uefaeuro-2020/match/2024445/',
                         'team_home' : 'North Macedonia',
                         'team_away' : 'Netherlands',
                         'goals_home' : 0,
                         'goals_away' : 3
                        },
                        {'url' : 'https://www.uefa.com/uefaeuro-2020/match/2024471/',
                         'team_home' : 'Czech Republic',
                         'team_away' : 'England',
                         'goals_home' : 0,
                         'goals_away' : 1,
                        },
                        {'url' : 'https://www.uefa.com/uefaeuro-2020/match/2024488/',
                         'team_home' : 'Czech Republic',
                         'team_away' : 'Denmark',
                         'goals_home' : 1,
                         'goals_away' : 2,
                        }
                       ]

# %%
df_matches_missing = pd.DataFrame(data = data_missing_matches)

# %%
# Aggregation of the crawled match information and the data added by hand
df_matches_em = pd.concat([df_matches_em_crawling[df_matches_em_crawling['team_home'].notnull()], df_matches_missing], axis = 0) \
                                                                                        .reset_index(drop = True)

# %%
cols_to_int = ['goals_home', 'goals_away']

for col in cols_to_int:
    df_matches_em[col] = df_matches_em[col].astype(int)

# %%
df_matches_em.head(5)
# Out:
#                                                  url    team_home  \
# 0  https://www.uefa.com/uefaeuro-2020/match/2024447/       Turkey
# 1  https://www.uefa.com/uefaeuro-2020/match/2024448/        Wales
# 2  https://www.uefa.com/uefaeuro-2020/match/2024457/       Turkey
# 3  https://www.uefa.com/uefaeuro-2020/match/2024458/        Italy
# 4  https://www.uefa.com/uefaeuro-2020/match/2024467/  Switzerland
#
#      team_away  goals_home  goals_away
# 0        Italy           0           3
# 1  Switzerland           1           1
# 2        Wales           0           2
# 3  Switzerland           3           0
# 4       Turkey           3           1

# %% [markdown]
# #### Export

# %%
file_name_euro_2020 = 'matches_euro_2020.xlsx'

df_matches_em.to_excel(os.path.join(path_output, file_name_euro_2020), index = False, encoding = 'iso-8859-1')
